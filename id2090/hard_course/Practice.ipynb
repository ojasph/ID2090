# %%
# Hello
## Introduction

# %%
# OOF

# %%
var('x','y')
exp = (y+3)/x-7
exp.show()
# Out:
# (y + 3)/x - 7

# %%
f = x^5 - 13*x^3 + 170

# %%
f.solve(x)
# Out:
# [0 == x^5 - 13*x^3 + 170]

# %%
f.roots(x, ring=CC)
# Out:
# [(-3.96559937392197, 1),
#  (-0.943579878430000 - 1.96570985931106*I, 1),
#  (-0.943579878430000 + 1.96570985931106*I, 1),
#  (2.92637956539099 - 0.673063365477829*I, 1),
#  (2.92637956539099 + 0.673063365477829*I, 1)]

# %%
plot3d(x^2, (1,2), (4,5))
# Out:
# Graphics3d Object

# %%
p1 = (x+2)^2
p1.expand().show()
# Out:
# x^2 + 4*x + 4

# %%
pi.n(digits = 301)
# Out:
# 3.

# %%
show(pi(digits = 100))
# Out:
# pi

# %%
R = RealField(256) 
R.pi()
print(R)
# Out:
# Real Field with 256 bits of precision

# %%
pi
# Out:
# pi

# %%
var('x', 'y')
p = x^2 + y^2

# %%
dpdx(x,y) = diff(p,x)
dpdx(x,y).show()
# Out:
# 2*x

# %%
help(infinity)
# Out:
# Help on PlusInfinity in module sage.rings.infinity object:
#
# class PlusInfinity(_uniq, AnInfinity, sage.structure.element.InfinityElement)
#  |  PlusInfinity(*args)
#  |
#  |  TESTS::
#  |
#  |      sage: oo == oo
#  |      True
#  |      sage: oo < oo
#  |      False
#  |      sage: -oo < oo
#  |      True
#  |      sage: -oo < 3 < oo
#  |      True
#  |
#  |      sage: unsigned_infinity == 3
#  |      False
#  |      sage: unsigned_infinity == unsigned_infinity
#  |      True
#  |      sage: unsigned_infinity == oo
#  |      True
#  |
#  |  Method resolution order:
#  |      PlusInfinity
#  |      _uniq
#  |      AnInfinity
#  |      sage.structure.element.InfinityElement
#  |      sage.structure.element.RingElement
#  |      sage.structure.element.ModuleElement
#  |      sage.structure.element.Element
#  |      sage.structure.sage_object.SageObject
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __hash__(self)
#  |      TESTS::
#  |
# ...

# %%
integral(e^(-x^2), x, -infinity, +infinity)
# Out:
# sqrt(pi)

# %%
n = CC(42)

# %%
n
# Out:
# 42.0000000000000

# %%
RR.dist(-1,2)
# Out:
# 3.00000000000000

# %%
f = piecewise([((0,pi/2),-1),((pi/2,pi),2)])
f.fourier_series_cosine_coefficient(1)
show(f.fourier_series_sine_coefficient(0))
s5 = f.fourier_series_partial_sum(10)
s5.show()
plot(f, -5,5)
# Out:
# 0
# -2/3*sin(18*x)/pi - 6/7*sin(14*x)/pi - 6/5*sin(10*x)/pi - 2*sin(6*x)/pi - 6*sin(2*x)/pi + 1/2
# verbose 0 (3791: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 137 points.
# verbose 0 (3791: plot.py, generate_plot_points) Last error message: 'point 5.0 is not in the domain'
# Graphics object consisting of 1 graphics primitive

# %%
from sage.plot.scatter_plot import ScatterPlot
ScatterPlot([0,1,2], [3.5,2,5.1], {'facecolor':'white', 'marker':'s'})
# Out:
# Scatter plot graphics primitive on 3 data points

# %%
from sage.plot.point import Point
P = point([1,2],[2,3],{'alpha':.5})
a = P[0]; a
b = a.plot3d()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-bfa7f3fcd0bf> in <module>
#       1 from sage.plot.point import Point
# ----> 2 P = point([Integer(1),Integer(2)],[Integer(2),Integer(3)],{'alpha':RealNumber('.5')})
#       3 a = P[Integer(0)]; a
#       4 b = a.plot3d()
#
# TypeError: point() takes 1 positional argument but 3 were given

# %%
A = point((1, 1))
a = A[0]; a
a.plot2d()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e80624af7ff1> in <module>
#       1 A = point((Integer(1), Integer(1)))
#       2 a = A[Integer(0)]; a
# ----> 3 a.plot2d()
#
# AttributeError: 'Point' object has no attribute 'plot2d'

# %%
xdata = [1,2,3]
ydata = [2,3,4]
for i in range(3):
    di = point((xdata[i],ydata[i]))
var('d')
d = 0
for i in range(3):
    d += di
    
d.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b77ec351ec8a> in <module>
#       6 d = Integer(0)
#       7 for i in range(Integer(3)):
# ----> 8     d += di
#       9
#      10 d.show()
#
# /usr/lib/python3/dist-packages/sage/rings/integer.pyx in sage.rings.integer.Integer.__add__ (build/cythonized/sage/rings/integer.c:12201)()
#    1779             return y
#    1780
# -> 1781         return coercion_model.bin_op(left, right, operator.add)
#    1782
#    1783     cpdef _add_(self, right):
#
# /usr/lib/python3/dist-packages/sage/structure/coerce.pyx in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:11101)()
#    1247             mul_method = getattr(y, '__r%s__'%op_name, None)
#    1248             if mul_method is not None:
# -> 1249                 res = mul_method(x)
# ...

# %%
from sage.plot.line import Line
Line([1,2], [1,5], {})
plot3d(z=0, **kwds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-97cf3db2bc2d> in <module>
#       1 from sage.plot.line import Line
#       2 Line([Integer(1),Integer(2)], [Integer(1),Integer(5)], {})
# ----> 3 plot3d(z=Integer(0), **kwds)
#
# NameError: name 'kwds' is not defined
