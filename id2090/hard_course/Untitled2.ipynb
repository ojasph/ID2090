# %%
xarray = [0,1,2,3,4,5,9]
yarray=[2.5, 0.5, 0.5, 2, 2, 1.5, 0]
var('x')
myData = list(zip(xarray, yarray))

var('d1, d2, d3, d4')
model2(x) = d1*x^3+ d2*x^2 + d3*x + d4
sol2 = find_fit(myData,model2, initial_guess=[1,2,3,4])
show(sol2)
# Out:
# [d1 == -0.03685205975477013,
#  d2 == 0.4561218676395813,
#  d3 == -1.3588114427995635,
#  d4 == 2.105109375912021]
# x |--> d1*x^3 + d2*x^2 + d3*x + d4

# %%
p = point(zip(xarray, yarray), color='red', size=30)
a = plot(-0.03685205975477013*x^3 + 0.4561218676395813*x^2 - 1.3588114427995635*x^1+ 2.105109375912021, x, [0,10])
# Display the plot
show(p + a)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(sol2[0]*x, x, [1,5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3/dist-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6755)()
#     725         try:
# --> 726             ind = self._vars.index(var_name)
#     727         except ValueError:
#
# ValueError: 'd1' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-9971271c4e14> in <module>
# ----> 1 plot(sol2[Integer(0)]*x, x, [Integer(1),Integer(5)])
#
# /usr/lib/python3/dist-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     491                 options['__original_opts'] = kwds
#     492             options.update(kwds)
# --> 493             return func(*args, **options)
#     494
# ...

# %%
var('x')
a = sin(x).taylor(x, 3.5,5)
a.show()
d = plot(sin(x), x, [2,7])
b = plot(a, x, [2,7], color = "red")
d + b
# Out:
# -0.007803805727423303*(x - 3.5)^5 - 0.01461596782040083*(x - 3.5)^4 + 0.156076114548466*(x - 3.5)^3 + 0.1753916138448099*(x - 3.5)^2 - 0.9364566872907963*x + 2.9268151778281672
# Graphics object consisting of 2 graphics primitives

# %%
var('d1, d2, d3, d4, d5, d6, d7')
model2(x) = d1*x^6+ d2*x^5 + d3*4 + d4*x^3 + d5*x^2 + d6*x+ d7
sol3 = find_fit(myData,model2, initial_guess=[1,2,3,4, 5, 6, 7])
show(sol3)
# Out:
# [d1 == -0.0002058882471027701,
#  d2 == 0.004060814784114353,
#  d3 == 3639385.2745140735,
#  d4 == -0.396986681092768,
#  d5 == 2.39271527777684,
#  d6 == -4.144452920887092,
#  d7 == -14557538.574059112]

# %%
print(sol2[1])
type(d2)
sol2[1].rhs()
# Out:
# d2 == 0.4561218676395813
# 0.4561218676395813

# %%
plot(sol2[0].rhs()*x^3+ sol2[1].rhs()*x^2 + sol2[2].rhs()*x + sol2[3].rhs(), x, [-4,4])
# Out:
# Graphics object consisting of 1 graphics primitive
